# %%
import json
from pandas import DataFrame, Series
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fs = pd.read_json('../full_dataset/featureset1.json')

# %%
plt.figure(figsize = (8, 5))
sns.countplot('elite_user', data = fs, palette = "Set2", alpha = 0.8)
plt.title('Yelp Elite vs. Non-Elite', fontsize = 14)
plt.savefig('elite.png', dpi = 800)

# %%
fs
# Out:
#        categories_avg_rating  categories_biz_count  categories_reviews  cool  \
# 0                   5.000000                     1                   1     0
# 1                   5.000000                     1                   1     0
# 10                  5.000000                     1                   1     0
# 100                 5.000000                     1                   1     0
# 1000                4.000000                     1                   1     1
# 10000               1.500000                     4                   4     1
# 10001               1.000000                     1                   1     0
# 10002               1.000000                    10                  10     1
# 10003               5.000000                     1                   1     0
# 10004               5.000000                     1                   1     1
# 10005               3.000000                     1                   1     0
# 10006               1.000000                     1                   1     2
# 10007               5.000000                     2                   2     0
# 10008               5.000000                     1                   1     0
# 10009               5.000000                     1                   1     0
# 1001                5.000000                     1                   1     1
# 10010               5.000000                     1                   1     0
# 10011               3.500000                     8                   8     9
# 10012               2.000000                     1                   1     1
# 10013               1.000000                     1                   1     0
# 10014               3.500000                     8                   8     2
# 10015               5.000000                     1                   1     0
# 10016               4.000000                     1                   1     1
# 10017               2.000000                     1                   1     0
# 10018               5.000000                     1                   1     0
# 10019               4.000000                     2                   2     3
# 1002                5.000000                     1                   1     0
# 10020               3.000000                     1                   1     0
# 10021               5.000000                     1                   1     0
# 10022               4.000000                     1                   1     0
# ...                      ...                   ...                 ...   ...
# 9972                1.000000                     1                   1     0
# 9973                5.000000                     1                   1     0
# 9974                1.000000                     1                   1     5
# 9975                5.000000                     1                   1     0
# 9976                1.000000                     1                   1     0
# 9977                4.000000                     1                   1     0
# 9978                5.000000                     1                   1     0
# 9979                2.000000                     1                   1     0
# 998                 1.000000                     1                   1     0
# 9980                3.000000                     1                   1     0
# 9981                5.000000                     1                   1     0
# 9982                5.000000                     1                   1     0
# 9983                5.000000                     1                   1     0
# 9984                4.000000                     6                   6     9
# 9985                5.000000                     1                   1     0
# 9986                2.000000                     1                   1     0
# 9987                1.000000                     1                   1     0
# 9988                5.000000                     1                   1     0
# 9989                1.000000                     1                   1     0
# 999                 1.000000                     1                   1     2
# 9990                5.000000                     1                   1     0
# 9991                5.000000                     1                   1     0
# 9992                3.000000                     1                   1     0
# 9993                5.000000                     1                   1     0
# 9994                1.000000                     1                   1     0
# 9995                3.333333                     3                   3     1
# 9996                2.000000                     1                   1     0
# 9997                4.000000                     1                   1     0
# 9998                5.000000                     1                   1     1
# 9999                4.000000                     1                   1     0
#
#       elite_user  funny  months_yelping  std_dev_rating  total_reviews  \
# 0      not_elite      0              17        0.000000              4
# 1      not_elite      0              13        0.000000              6
# 10     not_elite      0              16        0.000000              2
# 100    not_elite      0              38        0.000000              3
# 1000   not_elite      1              62        0.000000             23
# 10000  not_elite      4              54        0.866025             37
# define function to log transform variables
def log_transform(stat):
    if stat > 0:
        return np.log(stat)
    elif stat == 0:
        return np.log(stat + .001)
    else:
        return np.log(1 + stat)

# %%
print np.log(0.001)
# Out:
# -6.90775527898

# %%
fs['categories_avg_rating'] = fs.categories_avg_rating.apply(log_transform)
fs['categories_biz_count'] = fs.categories_biz_count.apply(log_transform)
fs['categories_reviews'] = fs.categories_reviews.apply(log_transform)
fs['cool'] = fs.cool.apply(log_transform)
fs['funny'] = fs.funny.apply(log_transform)
fs['months_yelping'] = fs.months_yelping.apply(log_transform)
#fs['std_dev_rating'] = fs.std_dev_rating.apply(log_transform)
fs['total_reviews'] = fs.total_reviews.apply(log_transform)
fs['useful'] = fs.useful.apply(log_transform)
fs
# Out:
#        categories_avg_rating  categories_biz_count  categories_reviews  \
# 0                   1.609438              0.000000            0.000000
# 1                   1.609438              0.000000            0.000000
# 10                  1.609438              0.000000            0.000000
# 100                 1.609438              0.000000            0.000000
# 1000                1.386294              0.000000            0.000000
# 10000               0.405465              1.386294            1.386294
# 10001               0.000000              0.000000            0.000000
# 10002               0.000000              2.302585            2.302585
# 10003               1.609438              0.000000            0.000000
# 10004               1.609438              0.000000            0.000000
# 10005               1.098612              0.000000            0.000000
# 10006               0.000000              0.000000            0.000000
# 10007               1.609438              0.693147            0.693147
# 10008               1.609438              0.000000            0.000000
# 10009               1.609438              0.000000            0.000000
# 1001                1.609438              0.000000            0.000000
# 10010               1.609438              0.000000            0.000000
# 10011               1.252763              2.079442            2.079442
# 10012               0.693147              0.000000            0.000000
# 10013               0.000000              0.000000            0.000000
# 10014               1.252763              2.079442            2.079442
# 10015               1.609438              0.000000            0.000000
# 10016               1.386294              0.000000            0.000000
# 10017               0.693147              0.000000            0.000000
# 10018               1.609438              0.000000            0.000000
# 10019               1.386294              0.693147            0.693147
# 1002                1.609438              0.000000            0.000000
# 10020               1.098612              0.000000            0.000000
# 10021               1.609438              0.000000            0.000000
# 10022               1.386294              0.000000            0.000000
# ...                      ...                   ...                 ...
# 9972                0.000000              0.000000            0.000000
# 9973                1.609438              0.000000            0.000000
# 9974                0.000000              0.000000            0.000000
# 9975                1.609438              0.000000            0.000000
# 9976                0.000000              0.000000            0.000000
# 9977                1.386294              0.000000            0.000000
# 9978                1.609438              0.000000            0.000000
# 9979                0.693147              0.000000            0.000000
# 998                 0.000000              0.000000            0.000000
# 9980                1.098612              0.000000            0.000000
# 9981                1.609438              0.000000            0.000000
# 9982                1.609438              0.000000            0.000000
# 9983                1.609438              0.000000            0.000000
# 9984                1.386294              1.791759            1.791759
# 9985                1.609438              0.000000            0.000000
# 9986                0.693147              0.000000            0.000000
# 9987                0.000000              0.000000            0.000000
# 9988                1.609438              0.000000            0.000000
# 9989                0.000000              0.000000            0.000000
# 999                 0.000000              0.000000            0.000000
# 9990                1.609438              0.000000            0.000000
# 9991                1.609438              0.000000            0.000000
# 10017       3.401197 -6.907755  MPrypfxPV-66xpZT30-nbQ
# 10018       2.484907 -6.907755  vNe_vTby9qE3wyxKY6IUgA
# 10019       2.197225  1.098612  qsq8a-Xa5FDzeDuLKzgXfg
# 1002        2.197225 -6.907755  ydxamHDJUYh1zbZC8wAwmg
# 10020       1.098612 -6.907755  RlzliTSkLaQquIf5t9URig
# 10021       0.693147  0.693147  CNnSi2vTv3VXQxkoRm6fFw
# 10022       2.944439  0.693147  Lc9LmBuK24mSrDluIs_8Gg
# ...              ...       ...                     ...
# 9972        0.693147 -6.907755  FL5Y9UDkslGrXuiA_EdrQw
# 9973        1.609438 -6.907755  XmchwD_ars8ab70g8R6qxw
# 9974        4.127134  1.945910  PYtryNSk30ytqOc_36sLPw
# 9975        2.197225  0.000000  fDXALtk5kBuQgUD5GLkrhg
# 9976        0.693147 -6.907755  51dpo_bzENSe0NihiozzxQ
# 9977        0.000000 -6.907755  R989VazqBaRqsRi8528ZbQ
# 9978        1.791759  0.000000  vu4UAlW-LosTKQOsXRCZ0g
# 9979        0.693147 -6.907755  J_oQck8-p39aSdL08mQeRQ
# 998         1.098612 -6.907755  1zdN0jKn4yYw2So652flXA
# 9980        2.484907 -6.907755  ojLvjplhR1NTRbwnksawAA
# 9981        0.000000 -6.907755  orrxn37xLl4x2kQtu75K5w
# 9982        0.000000 -6.907755  _P7CuAHtYcOR2Ji0MQDy-g
# 9983        0.000000  0.000000  80zHSghiqqKPgp34gWmBNQ
# 9984        4.330733  2.484907  Ov0aEN7LxyFsqehzpX1q6g
# 9985        1.945910  1.609438  v2NsLW-phtOVHKP5R1j0qQ
# 9986        0.693147 -6.907755  f25F1X_AtcE2RHHL2mSnCw
# 9987        0.000000 -6.907755  Bvd_GPMBDpSyhAMzM7NRow
# 9988        2.995732 -6.907755  W4--OcZwuBnUXYoTgnBiQA
# 9989        0.000000 -6.907755  3lw-oOSA1QkytHpLyadnEw
# 999         0.000000  1.386294  iW4dPjlhSPXDE-NG3CIoDQ
# 9990        2.484907 -6.907755  VO3_9Vwklm6xaZPV7-6Esw
# 9991        0.693147 -6.907755  z9vUg0LjRYhsuLbrTOzohA
# 9992        1.609438 -6.907755  gjsckOlv8DZAIwBz4tmQdw
# 9993        0.000000 -6.907755  kz0qy3Q5GaqXz1BgpwpTIQ
# 9994        1.609438 -6.907755  6W5twqCjteHEWtL3r4J-LQ
# 9995        3.784190  1.098612  VA5zvXwaaj81_tjiQCH2mg
# 9996        1.386294 -6.907755  NNIQUNwZ1BDhaw-Kce_ytA
# 9997        0.000000 -6.907755  cNjgpb7xNnBL6ykf6NtNEQ
# 9998        2.397895  1.098612  7fQoDyjMzaY0eEghUizEUQ
# 9999        0.000000 -6.907755  bC0V5qnfex0gdJ5b1SWgkA
#
# [46577 rows x 11 columns]

# %%
fs['is_train'] = np.random.uniform(0,1,len(fs)) <= .66

# %%
train, test = fs[fs['is_train']==True], fs[fs['is_train']==False]

# %%
#https://github.com/dianalam/yelp-classifier/blob/master/yelp-classification.ipynb
from sklearn.pipeline import Pipeline, make_pipeline
from collections import defaultdict
def grid_search_scores_rf(Xtrain, ytrain):
    scores = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']
    output = defaultdict(list)
    pipeline = make_pipeline(StandardScaler(), RandomForestClassifier())
    param = {
        'randomforestclassifier__max_features': ['auto', 'log2', None],
        'randomforestclassifier__min_samples_leaf': [1, 5, 10, 50, 100, 200, 500]}
    for score in scores: 
        #print score, '\n'
        grid_search = GridSearchCV(pipeline, param_grid = param, verbose = 3, cv = 5, scoring = score)
        grid_search.fit(Xtrain, ytrain)
        output[score] = grid_search.best_score_, grid_search.best_params_
    return output

# %%
features = pd.Index([
           'categories_avg_rating',
           'categories_reviews',
           'cool',
           'funny',
           'months_yelping',
           'std_dev_rating',
           'total_reviews',
           'useful'
          ])

# %%
from sklearn.preprocessing import normalize, scale, StandardScaler, Normalizer
from sklearn.grid_search import GridSearchCV
y, _ = pd.factorize(train['elite_user'])
#np.set_printoptions(threshold='nan')
print y
grid_search_scores_rf(train[features], y)
# Out:
# [0 0 0 ..., 0 0 0]
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto, score=0.880052 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto, score=0.881022 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto, score=0.879709 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto, score=0.878072 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto, score=0.876617 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto, score=0.894601 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto, score=0.894762 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto, score=0.894584 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto, score=0.896669 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto, score=0.893273 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto, score=0.894924 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto, score=0.897026 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto, score=0.895554 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto, score=0.896184 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto, score=0.894243 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto, score=0.895247 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto, score=0.891044 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto, score=0.895069 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto, score=0.892303 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto, score=0.896507 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto, score=0.894762 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto, score=0.892499 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto, score=0.892805 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto, score=0.891656 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto, score=0.891332 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto, score=0.893469 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto, score=0.888458 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto, score=0.884883 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto, score=0.885996 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto, score=0.889230 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto, score=0.888134 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto, score=0.886680 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto, score=0.884559 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto
# [Parallel(n_jobs=1)]: Done  31 tasks       | elapsed:    4.5s
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto, score=0.884541 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto, score=0.885349 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2, score=0.879243 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2, score=0.882477 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2, score=0.880032 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2, score=0.880821 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2, score=0.878881 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2, score=0.892661 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2, score=0.895247 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2, score=0.894260 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2, score=0.891656 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2, score=0.891171 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2, score=0.893792 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2, score=0.894439 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2, score=0.899272 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2, score=0.895052 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2, score=0.895213 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2, score=0.895732 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2, score=0.895086 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2, score=0.894584 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2, score=0.893758 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2, score=0.894243 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2, score=0.894116 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2, score=0.892984 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2, score=0.892805 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2, score=0.891656 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2, score=0.892303 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2, score=0.893146 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2, score=0.888296 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2, score=0.889733 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2, score=0.890362 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2, score=0.890686 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=log2, score=0.890721 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=log2, score=0.888134 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=log2, score=0.885206 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=log2, score=0.885026 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=log2, score=0.886320 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=None, score=0.875687 -   0.4s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=None, score=0.881022 -   0.4s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=None, score=0.881487 -   0.4s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=None, score=0.877102 -   0.4s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=None, score=0.877587 -   0.4s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=None, score=0.892338 -   0.3s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=None, score=0.896217 -   0.3s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=None, score=0.895392 -   0.3s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=None, score=0.893111 -   0.3s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=None, score=0.890847 -   0.3s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=None, score=0.894924 -   0.3s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=None, score=0.895732 -   0.3s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=None, score=0.898626 -   0.3s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=None, score=0.894890 -   0.3s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=None, score=0.891332 -   0.3s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=None, score=0.893146 -   0.3s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=None, score=0.893469 -   0.3s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=None, score=0.893937 -   0.3s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=None, score=0.896184 -   0.3s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=None, score=0.894243 -   0.3s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=None, score=0.893469 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=None, score=0.893307 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=None, score=0.893290 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=None, score=0.891656 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=None, score=0.892141 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=None, score=0.894116 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=None, score=0.891853 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=None, score=0.889410 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=None, score=0.889554 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=None, score=0.890686 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=None, score=0.885710 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=None, score=0.888134 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=None, score=0.886985 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=None, score=0.885834 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=None
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=None, score=0.886481 -   0.2s
# [Parallel(n_jobs=1)]: Done 105 out of 105 | elapsed:   20.1s finished
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto, score=0.579158 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto, score=0.590822 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto, score=0.600775 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto, score=0.587879 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=auto, score=0.549488 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto, score=0.704918 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto, score=0.678733 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto, score=0.712871 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto, score=0.696602 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=auto, score=0.680085 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto, score=0.700000 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto, score=0.702899 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto, score=0.726064 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto, score=0.720930 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=auto, score=0.678815 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto, score=0.748447 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto, score=0.742690 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto, score=0.751462 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto, score=0.752542 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=auto, score=0.726542 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto, score=0.760714 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto, score=0.749226 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto, score=0.756184 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto, score=0.744275 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=auto, score=0.754967 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto, score=0.745098 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto, score=0.757812 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto, score=0.746711 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto, score=0.770833 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=auto, score=0.738562 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto, score=0.798165 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto, score=0.754237 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto
# [Parallel(n_jobs=1)]: Done  31 tasks       | elapsed:    4.2s
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto, score=0.751295 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto, score=0.765000 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=auto, score=0.755187 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2, score=0.584795 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2, score=0.588571 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2, score=0.583162 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2, score=0.576375 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=1, randomforestclassifier__max_features=log2, score=0.556131 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2, score=0.659389 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2, score=0.675052 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2, score=0.683371 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2, score=0.699507 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=5, randomforestclassifier__max_features=log2, score=0.648330 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2, score=0.709832 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2, score=0.699095 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2, score=0.738693 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2, score=0.693827 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=10, randomforestclassifier__max_features=log2, score=0.692308 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2, score=0.715040 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2, score=0.710723 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2, score=0.732782 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2, score=0.732044 -   0.2s
# [CV] randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=50, randomforestclassifier__max_features=log2, score=0.714286 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2, score=0.737288 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2, score=0.729107 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2, score=0.717514 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2, score=0.736156 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=100, randomforestclassifier__max_features=log2, score=0.693506 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2, score=0.754658 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2, score=0.738832 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2, score=0.735786 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2, score=0.757353 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=200, randomforestclassifier__max_features=log2, score=0.732704 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=log2, score=0.770492 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=log2, score=0.762115 -   0.1s
# [CV] randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=log2
# [CV]  randomforestclassifier__min_samples_leaf=500, randomforestclassifier__max_features=log2, score=0.764706 -   0.1s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-13e638d03919> in <module>()
#       4 #np.set_printoptions(threshold='nan')
#       5 print y
# ----> 6 grid_search_scores_rf(train[features], y)
#
# <ipython-input-10-4a08e4f49167> in grid_search_scores_rf(Xtrain, ytrain)
#      12         #print score, '\n'
#      13         grid_search = GridSearchCV(pipeline, param_grid = param, verbose = 3, cv = 5, scoring = score)
# ---> 14         grid_search.fit(Xtrain, ytrain)
#      15         output[score] = grid_search.best_score_, grid_search.best_params_
#      16     return output
#
# /Users/aalkhatib/anaconda/lib/python2.7/site-packages/sklearn/grid_search.pyc in fit(self, X, y)
#     802
#     803         """
# --> 804         return self._fit(X, y, ParameterGrid(self.param_grid))
#     805
#     806
#
# /Users/aalkhatib/anaconda/lib/python2.7/site-packages/sklearn/grid_search.pyc in _fit(self, X, y, parameter_iterable)
#     551                                     self.fit_params, return_parameters=True,
#     552                                     error_score=self.error_score)
# --> 553                 for parameters in parameter_iterable
#     554                 for train, test in cv)
#     555
#
# /Users/aalkhatib/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     802             self._iterating = True
#     803
# --> 804             while self.dispatch_one_batch(iterator):
#     805                 pass
#     806
#
# /Users/aalkhatib/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     660                 return False
#     661             else:
# --> 662                 self._dispatch(tasks)
#     663                 return True
#     664
#
# /Users/aalkhatib/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     568
#     569         if self._pool is None:
# --> 570             job = ImmediateComputeBatch(batch)
#     571             self._jobs.append(job)
#     572             self.n_dispatched_batches += 1
#
# /Users/aalkhatib/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __init__(self, batch)
#     181         # Don't delay the application, to avoid keeping the input
#     182         # arguments in memory
# --> 183         self.results = batch()
#     184
#     185     def get(self):
#
# /Users/aalkhatib/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#      70
#      71     def __call__(self):
# ---> 72         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#      73
#      74     def __len__(self):
#
# KeyboardInterrupt:

# %%
best_randomforest = RandomForestClassifier(min_samples_leaf = 10, max_features = 'log2')
best_randomforest.fit(train[features], y)
None

# %%
target_names = np.array(["not_elite", "elite"])

# %%
preds = target_names[best_randomforest.predict(test[features])]

# %%
pd.crosstab(test['elite_user'], preds, rownames=['actual'], colnames=['preds'])

# %%
from sklearn import metrics

# %%
print metrics.classification_report(test['elite_user'], preds)
